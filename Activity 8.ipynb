# %% [markdown]
# #### Examing relationship between storefront locations and features about their area

# %% [markdown]
# This information includes the revenue of the storefront at each location, the age of the location in years, and information about the surrounding area (in a 20 mileradius), such as the number of competitors, the median
# income of the area, the number of members enrolled on the company's loyalty rewards program living in the area, and the population density of the area. You've been asked to explore this data and look for how these features are related to the revenue of the storefront in that location. Use correlations and visualizations to explore the data.

# %% [markdown]
# 2. Use seaborn's pairplot function to visualize the data and its relationships.
# 3. Finally, use correlations to investigate the relationship between the different variables and location revenue.

# %%
import pandas as pd

df = pd.read_csv('data_science/location_rev.csv')
df.head()
# Out:
#     revenue  num_competitors  median_income  num_loyalty_members  \
# 0  42247.80              3.0       30527.57               1407.0
# 1  38628.37              3.0       30185.49               1025.0
# 2  39715.16              1.0       32182.24               1498.0
# 3  35593.30              5.0       29728.65               2340.0
# 4  35128.18              4.0       30691.17                847.0
#
#    population_density  location_age
# 0              3302.0          12.0
# 1              4422.0          11.0
# 2              3260.0          12.0
# 3              4325.0          10.0
# 4              3774.0          11.0

# %%
import seaborn as sns
# %matplotlib inline

sns.pairplot(df)

# %%
df.corr()
# Out:
#                       revenue  num_competitors  median_income  \
# revenue              1.000000        -0.156685       0.601888
# num_competitors     -0.156685         1.000000      -0.018398
# median_income        0.601888        -0.018398       1.000000
# num_loyalty_members  0.173432        -0.027283       0.011891
# population_density   0.311653         0.035768      -0.041697
# location_age         0.552773         0.053796       0.045621
#
#                      num_loyalty_members  population_density  location_age
# revenue                         0.173432            0.311653      0.552773
# num_competitors                -0.027283            0.035768      0.053796
# median_income                   0.011891           -0.041697      0.045621
# num_loyalty_members             1.000000           -0.028611      0.036016
# population_density             -0.028611            1.000000     -0.009977
# location_age                    0.036016           -0.009977      1.000000
