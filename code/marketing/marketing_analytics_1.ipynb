# %% [markdown]
# ### Data Models and Structured Data

# %% [markdown]
# A data model:
#    * Structured Data = completely structured or wellstructured data, flat tabular form, no duplicate columns
#    * Semistructured data = variable lengths, different data types (numerical or categorical) in same column,nested or hierarchical tabular structure, columns (attributes)-no duplicates, rows(observations)-may be, may be missing values, stored accurately in NoSQL databases, Apache Parquet files, JSON files, and so on.
#    * Unstructured data =  may not be tabular, even if it is tabular, the number of attributes or columns per observation may be completely arbitrary, can be stored as text files, CSV files, Excel files, images, audio clips, same data could be represented in different arrays, the attributes might not match each other, with values leaking into other parts

# %%
import pandas as pd

# %%
user_info = pd.read_json("data_science/user_info.json")
user_info.head()
# Out:
#                         _id  index                                  guid  \
# 0  5c0a28d7a647437fd3d3a6aa      0  832f1af4-fb18-4ba8-b032-f4cbf343dbe9
# 1  5c0a28d780f6278b11586ab1      1  4306cb37-9506-48c2-8ccf-e69a063589ee
# 2  5c0a28d722e2e29d9bce2b64      2  5019e436-7cc4-48ee-a384-3483131f8ee1
# 3  5c0a28d76b5e8859a754cb4f      3  d2c4b1eb-2974-463a-b288-d1dae5dec187
# 4  5c0a28d7ebb99c08e2288c76      4  df0b59ed-2e81-43f1-9ae0-16f138e738be
#
#    isActive    balance                    picture  age eyeColor  \
# 0     False  $3,806.93  http://placehold.it/32x32   20    green
# 1      True  $3,330.01  http://placehold.it/32x32   22    brown
# 2      True  $1,619.46  http://placehold.it/32x32   40    green
# 3     False  $3,334.12  http://placehold.it/32x32   29     blue
# 4     False  $1,368.48  http://placehold.it/32x32   33    brown
#
#                  name  gender  ...              phone  \
# 0         Grace Berry  female  ...  +1 (814) 555-3298
# ...

# %%
user_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   _id            6 non-null      object
#  1   index          6 non-null      int64
#  2   guid           6 non-null      object
#  3   isActive       6 non-null      bool
#  4   balance        6 non-null      object
#  5   picture        6 non-null      object
#  6   age            6 non-null      int64
#  7   eyeColor       6 non-null      object
#  8   name           6 non-null      object
#  9   gender         6 non-null      object
#  10  company        6 non-null      object
#  11  email          6 non-null      object
#  12  phone          6 non-null      object
#  13  address        6 non-null      object
#  14  about          6 non-null      object
#  15  registered     6 non-null      object
#  16  latitude       6 non-null      float64
# ...

# %%
user_info.shape
# Out:
# (6, 22)

# %% [markdown]
# ### IDENTIFYING SEMI-STRUCTURED AND UNSTRUCTURED DATA

# %%
campaign_data = pd.read_csv("data_science/data.csv", header=1)
campaign_data.head()
# Out:
#     views  likes
# 0   90006    402
# 1  101141    389
# 2   97297    403
# 3  117182    397
# 4   99637    404

# %%
campaign_data.tail()
# Out:
#      views  likes
# 95  100464    391
# 96   96382    387
# 97   94971    389
# 98  103070    410
# 99  110387    411

# %%
campaign_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   views   100 non-null    int64
#  1   likes   100 non-null    int64
# dtypes: int64(2)
# memory usage: 1.7 KB

# %%
campaign_data.shape
# Out:
# (100, 2)

# %%
sales = pd.read_excel("data_science/sales.xlsx")
sales.head()
# Out:
#    Year  Product       line Product.1  type  Product.2  Order method  \
# 0  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 1  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 2  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 3  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
# 4  2004  Camping  Equipment   Cooking  Gear  TrailChef  Water    Bag
#
#       type.1 Retailer  ...  Quantity        Unit    cost.1 Unit.1 price  \
# 0  Telephone   United  ...      6.59  156672.570  5.195714    NaN   NaN
# 1  Telephone   Canada  ...   7145.88       6.190       NaN    NaN   NaN
# 2  Telephone   Mexico  ...       NaN         NaN       NaN    NaN   NaN
# 3  Telephone   Brazil  ...       NaN         NaN       NaN    NaN   NaN
# 4  Telephone    Japan  ...  91707.18       5.488       NaN    NaN   NaN
#
#    Gross  profit  Unit.2  sale  price.1
# 0    NaN     NaN     NaN   NaN      NaN
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65535 entries, 0 to 65534
# Data columns (total 26 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Year       65535 non-null  int64
#  1   Product    65535 non-null  object
#  2   line       65535 non-null  object
#  3   Product.1  65535 non-null  object
#  4   type       65535 non-null  object
#  5   Product.2  65535 non-null  object
#  6   Order      65535 non-null  object
#  7   method     61083 non-null  object
#  8   type.1     46709 non-null  object
#  9   Retailer   32525 non-null  object
#  10  country    24135 non-null  object
#  11  Revenue    21494 non-null  object
#  12  Planned    20925 non-null  object
#  13  revenue    20645 non-null  object
#  14  Product.3  20588 non-null  object
#  15  cost       19224 non-null  float64
#  16  Quantity   13663 non-null  float64
#  17  Unit       7046 non-null   float64
#  18  cost.1     2403 non-null   float64
# ...

# %% [markdown]
# ### Data Manipulation - Basics

# %%
pd.DataFrame({'category': pd.Series([1, 2, 3])})
# Out:
#    category
# 0         1
# 1         2
# 2         3

# %%
pd.DataFrame([1, 2, 3], columns=['category'])
# Out:
#    category
# 0         1
# 1         2
# 2         3

# %%
pd.DataFrame.from_dict({'category': [1, 2, 3]})
# Out:
#    category
# 0         1
# 1         2
# 2         3

# %%
pd.DataFrame(pd.Series([1, 2, 3]), columns=['category'])
# Out:
#    category
# 0         1
# 1         2
# 2         3

# %%
import copy

# %%
df1 = pd.DataFrame({'category': pd.Series([1, 2, 3])})
df1.head()
# Out:
#    category
# 0         1
# 1         2
# 2         3

# %%
df = copy.copy(df1)
df.head()
# Out:
#    category
# 0         1
# 1         2
# 2         3

# %%
df['cities'] = pd.Series([['Delhi', 'Mumbai'], ['Lucknow', 'Bhopal'],
                         ['Chennai', 'Banglalore']])
df.head()
# Out:
#    category                 cities
# 0         1        [Delhi, Mumbai]
# 1         2      [Lucknow, Bhopal]
# 2         3  [Chennai, Banglalore]

# %%
df = df.assign(young_viewers = pd.Series([2000000, 3000000, 1500000]),
          adult_viewers = pd.Series([2500000, 3500000, 1600000]),
          aged_viewers = pd.Series([2300000, 2800000, 2000000]))

# %%
df.head()
# Out:
#    category                 cities  young_viewers  adult_viewers  aged_viewers
# 0         1        [Delhi, Mumbai]        2000000        2500000       2300000
# 1         2      [Lucknow, Bhopal]        3000000        3500000       2800000
# 2         3  [Chennai, Banglalore]        1500000        1600000       2000000

# %%
df = df.append({'cities': ['Kolkata', 'Hyderabad'], 'adult_viewers': 2000000,
          'aged_viewers': 2000000, 'young_viewers': 1500000}, 
         ignore_index=True)

# %%
df.head()
# Out:
#    category                 cities  young_viewers  adult_viewers  aged_viewers
# 0       1.0        [Delhi, Mumbai]        2000000        2500000       2300000
# 1       2.0      [Lucknow, Bhopal]        3000000        3500000       2800000
# 2       3.0  [Chennai, Banglalore]        1500000        1600000       2000000
# 3       NaN   [Kolkata, Hyderabad]        1500000        2000000       2000000

# %%
df2 = pd.concat([df, df], sort=False)
df2
# Out:
#    category                 cities  young_viewers  adult_viewers  aged_viewers
# 0       1.0        [Delhi, Mumbai]        2000000        2500000       2300000
# 1       2.0      [Lucknow, Bhopal]        3000000        3500000       2800000
# 2       3.0  [Chennai, Banglalore]        1500000        1600000       2000000
# 3       NaN   [Kolkata, Hyderabad]        1500000        2000000       2000000
# 0       1.0        [Delhi, Mumbai]        2000000        2500000       2300000
# 1       2.0      [Lucknow, Bhopal]        3000000        3500000       2800000
# 2       3.0  [Chennai, Banglalore]        1500000        1600000       2000000
# 3       NaN   [Kolkata, Hyderabad]        1500000        2000000       2000000

# %%
df.drop([3])
# Out:
#    category                 cities  young_viewers  adult_viewers  aged_viewers
# 0       1.0        [Delhi, Mumbai]        2000000        2500000       2300000
# 1       2.0      [Lucknow, Bhopal]        3000000        3500000       2800000
# 2       3.0  [Chennai, Banglalore]        1500000        1600000       2000000

# %%
df
# Out:
#    category                 cities  young_viewers  adult_viewers  aged_viewers
# 0       1.0        [Delhi, Mumbai]        2000000        2500000       2300000
# 1       2.0      [Lucknow, Bhopal]        3000000        3500000       2800000
# 2       3.0  [Chennai, Banglalore]        1500000        1600000       2000000
# 3       NaN   [Kolkata, Hyderabad]        1500000        2000000       2000000

# %%
df.drop(['aged_viewers'], axis=1)
# Out:
#    category                 cities  young_viewers  adult_viewers
# 0       1.0        [Delhi, Mumbai]        2000000        2500000
# 1       2.0      [Lucknow, Bhopal]        3000000        3500000
# 2       3.0  [Chennai, Banglalore]        1500000        1600000
# 3       NaN   [Kolkata, Hyderabad]        1500000        2000000

# %%
df.drop('cities', axis=1).drop_duplicates()
# Out:
#    category  young_viewers  adult_viewers  aged_viewers
# 0       1.0        2000000        2500000       2300000
# 1       2.0        3000000        3500000       2800000
# 2       3.0        1500000        1600000       2000000
# 3       NaN        1500000        2000000       2000000

# %%
df['adult_viewers'].drop_duplicates()
# Out:
# 0    2500000
# 1    3500000
# 2    1600000
# 3    2000000
# Name: adult_viewers, dtype: int64

# %%
pd.merge(df, df1, how='right')
# Out:
#    category                 cities  young_viewers  adult_viewers  aged_viewers
# 0       1.0        [Delhi, Mumbai]        2000000        2500000       2300000
# 1       2.0      [Lucknow, Bhopal]        3000000        3500000       2800000
# 2       3.0  [Chennai, Banglalore]        1500000        1600000       2000000

# %%
pd.merge(df, df1, how='outer')
# Out:
#    category                 cities  young_viewers  adult_viewers  aged_viewers
# 0       1.0        [Delhi, Mumbai]        2000000        2500000       2300000
# 1       2.0      [Lucknow, Bhopal]        3000000        3500000       2800000
# 2       3.0  [Chennai, Banglalore]        1500000        1600000       2000000
# 3       NaN   [Kolkata, Hyderabad]        1500000        2000000       2000000

# %%
df.interpolate() # df.fillna(df.mean()), df.fillna(df.median()), df.fillna(-1)
# Out:
#    category                 cities  young_viewers  adult_viewers  aged_viewers
# 0       1.0        [Delhi, Mumbai]        2000000        2500000       2300000
# 1       2.0      [Lucknow, Bhopal]        3000000        3500000       2800000
# 2       3.0  [Chennai, Banglalore]        1500000        1600000       2000000
# 3       3.0   [Kolkata, Hyderabad]        1500000        2000000       2000000

# %%
df.isnull()
# Out:
#    category  cities  young_viewers  adult_viewers  aged_viewers
# 0     False   False          False          False         False
# 1     False   False          False          False         False
# 2     False   False          False          False         False
# 3      True   False          False          False         False

# %%
df[['category']].isna
# Out:
# <bound method DataFrame.isna of    category
# 0       1.0
# 1       2.0
# 2       3.0
# 3       NaN>

# %%
import numpy as np

# %%
df1 = pd.DataFrame()
df2 = pd.DataFrame()

# %%
df1['viewers'] = ["Sushmita", "Aditya", "Bala", "Anurag"]
df2['users'] = ["Aditya", "Anurag", "Bala", "Shushmita", "Apoorva"]

# %%
np.random.seed(1729)
df1 = df1.assign(views = np.random.normal(100, 100, 4))
df2 = df2.assign(cost = [20, np.nan, 15, 2, 7])

# %%
df1.head()
# Out:
#     viewers       views
# 0  Sushmita   31.266056
# 1    Aditya   17.900529
# 2      Bala  265.236086
# 3    Anurag   42.470696

# %%
df2.head()
# Out:
#        users  cost
# 0     Aditya  20.0
# 1     Anurag   NaN
# 2       Bala  15.0
# 3  Shushmita   2.0
# 4    Apoorva   7.0

# %%
df4 = df1.merge(df2, left_on="viewers", right_on="users", how="left")
df4.head()
# Out:
#     viewers       views   users  cost
# 0  Sushmita   31.266056     NaN   NaN
# 1    Aditya   17.900529  Aditya  20.0
# 2      Bala  265.236086    Bala  15.0
# 3    Anurag   42.470696  Anurag   NaN

# %%
df4.fillna(df.mean())
# Out:
#     viewers       views   users  cost
# 0  Sushmita   31.266056     NaN   NaN
# 1    Aditya   17.900529  Aditya  20.0
# 2      Bala  265.236086    Bala  15.0
# 3    Anurag   42.470696  Anurag   NaN

# %%
df['viewers'] = df['adult_viewers'] + df['aged_viewers'] + df['young_viewers']
df
# Out:
#    category                 cities  young_viewers  adult_viewers  \
# 0       1.0        [Delhi, Mumbai]        2000000        2500000
# 1       2.0      [Lucknow, Bhopal]        3000000        3500000
# 2       3.0  [Chennai, Banglalore]        1500000        1600000
# 3       NaN   [Kolkata, Hyderabad]        1500000        2000000
#
#    aged_viewers  viewers
# 0       2300000  6800000
# 1       2800000  9300000
# 2       2000000  5100000
# 3       2000000  5500000

# %%
df['expected clicks'] = 0.03 * df['viewers']
df
# Out:
#    category                 cities  young_viewers  adult_viewers  \
# 0       1.0        [Delhi, Mumbai]        2000000        2500000
# 1       2.0      [Lucknow, Bhopal]        3000000        3500000
# 2       3.0  [Chennai, Banglalore]        1500000        1600000
# 3       NaN   [Kolkata, Hyderabad]        1500000        2000000
#
#    aged_viewers  viewers  expected clicks
# 0       2300000  6800000         204000.0
# 1       2800000  9300000         279000.0
# 2       2000000  5100000         153000.0
# 3       2000000  5500000         165000.0

# %%
for row in df.itertuples(index=False):
    print(row)
# Out:
# Pandas(category=1.0, cities=['Delhi', 'Mumbai'], young_viewers=2000000, adult_viewers=2500000, aged_viewers=2300000, viewers=6800000, _6=204000.0)
# Pandas(category=2.0, cities=['Lucknow', 'Bhopal'], young_viewers=3000000, adult_viewers=3500000, aged_viewers=2800000, viewers=9300000, _6=279000.0)
# Pandas(category=3.0, cities=['Chennai', 'Banglalore'], young_viewers=1500000, adult_viewers=1600000, aged_viewers=2000000, viewers=5100000, _6=153000.0)
# Pandas(category=nan, cities=['Kolkata', 'Hyderabad'], young_viewers=1500000, adult_viewers=2000000, aged_viewers=2000000, viewers=5500000, _6=165000.0)

# %%
for row in df.itertuples(name="Monhtly"):
    print(row)
# Out:
# Monhtly(Index=0, category=1.0, cities=['Delhi', 'Mumbai'], young_viewers=2000000, adult_viewers=2500000, aged_viewers=2300000, viewers=6800000, _7=204000.0)
# Monhtly(Index=1, category=2.0, cities=['Lucknow', 'Bhopal'], young_viewers=3000000, adult_viewers=3500000, aged_viewers=2800000, viewers=9300000, _7=279000.0)
# Monhtly(Index=2, category=3.0, cities=['Chennai', 'Banglalore'], young_viewers=1500000, adult_viewers=1600000, aged_viewers=2000000, viewers=5100000, _7=153000.0)
# Monhtly(Index=3, category=nan, cities=['Kolkata', 'Hyderabad'], young_viewers=1500000, adult_viewers=2000000, aged_viewers=2000000, viewers=5500000, _7=165000.0)

# %%
for label, content in df.iterrows():
    print(label, content['viewers'], getattr(content, 'expected clicks'))
# Out:
# 0 6800000 204000.0
# 1 9300000 279000.0
# 2 5100000 153000.0
# 3 5500000 165000.0

# %%
for label, content in df.iteritems():
    print(label, content[1])
# Out:
# category 2.0
# cities ['Lucknow', 'Bhopal']
# young_viewers 3000000
# adult_viewers 3500000
# aged_viewers 2800000
# viewers 9300000
# expected clicks 279000.0

# %%
df['category'].map({1: 'a', 2: 'b', 3:'c', 4:'d'})
# Out:
# 0      a
# 1      b
# 2      c
# 3    NaN
# Name: category, dtype: object

# %%
df[['young_viewers', 'viewers']].apply(lambda x: (x[0]*1.0)/x[1], axis=1)
# Out:
# 0    0.294118
# 1    0.322581
# 2    0.294118
# 3    0.272727
# dtype: float64

# %%
df.groupby('aged_viewers')['expected clicks'].sum()
# Out:
# aged_viewers
# 2000000    318000.0
# 2300000    204000.0
# 2800000    279000.0
# Name: expected clicks, dtype: float64

# %%
df.groupby('aged_viewers')[['cities']].sum()
# Out:
#                                                  cities
# aged_viewers
# 2000000       [Chennai, Banglalore, Kolkata, Hyderabad]
# 2300000                                 [Delhi, Mumbai]
# 2800000                               [Lucknow, Bhopal]

# %% [markdown]
# ### APPLYING DATA TRANSFORMATIONS

# %%
user_info
# Out:
#                         _id  index                                  guid  \
# 0  5c0a28d7a647437fd3d3a6aa      0  832f1af4-fb18-4ba8-b032-f4cbf343dbe9
# 1  5c0a28d780f6278b11586ab1      1  4306cb37-9506-48c2-8ccf-e69a063589ee
# 2  5c0a28d722e2e29d9bce2b64      2  5019e436-7cc4-48ee-a384-3483131f8ee1
# 3  5c0a28d76b5e8859a754cb4f      3  d2c4b1eb-2974-463a-b288-d1dae5dec187
# 4  5c0a28d7ebb99c08e2288c76      4  df0b59ed-2e81-43f1-9ae0-16f138e738be
# 5  5c0a28d749ce43912931715e      5  1d4dcbcd-c5b7-45a8-9650-82d7f98305c6
#
#    isActive    balance                    picture  age eyeColor  \
# 0     False  $3,806.93  http://placehold.it/32x32   20    green
# 1      True  $3,330.01  http://placehold.it/32x32   22    brown
# 2      True  $1,619.46  http://placehold.it/32x32   40    green
# 3     False  $3,334.12  http://placehold.it/32x32   29     blue
# 4     False  $1,368.48  http://placehold.it/32x32   33    brown
# 5      True  $2,441.66  http://placehold.it/32x32   23    green
#
# ...

# %%
user_info['friends'][0]
# Out:
# [{'id': 0, 'name': 'Small Pena'},
#  {'id': 1, 'name': 'Sherry Mayo'},
#  {'id': 2, 'name': 'Medina Mcclain'}]

# %%
user_info['friends'].map(lambda x: len(x))
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3
# 5    3
# Name: friends, dtype: int64

# %%
user_info['tags'].apply(lambda x: [t.upper() for t in x])
# Out:
# 0    [EU, ID, FUGIAT, DESERUNT, NULLA, PROIDENT, LA...
# 1    [DESERUNT, DO, ADIPISICING, IN, ALIQUA, DUIS, ...
# 2    [ADIPISICING, CILLUM, DESERUNT, AUTE, IPSUM, C...
# 3    [ADIPISICING, VENIAM, DOLOR, DUIS, AUTE, TEMPO...
# 4    [QUI, AUTE, VOLUPTATE, EIUSMOD, EST, EST, CUPI...
# 5    [DOLORE, EIUSMOD, LABORUM, DOLORE, ALIQUIP, AL...
# Name: tags, dtype: object

# %%
# Checking distribution of eyeColor

user_info.groupby('eyeColor')['_id'].count()
# Out:
# eyeColor
# blue     1
# brown    2
# green    3
# Name: _id, dtype: int64

# %%
user_info.groupby('favoriteFruit')['_id'].count()
# Out:
# favoriteFruit
# apple         3
# strawberry    3
# Name: _id, dtype: int64
